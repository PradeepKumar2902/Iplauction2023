# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline 
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd


ipl = pd.read_csv(r'C:\Users\Admin\Desktop\IPL2024DATASET.csv')

# %%
ipl.head()
# Out:
#    Unnamed: 0           Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0           0  Spencer Johnson    5000000        BOWLER             10.0
# 1           1    Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2           2      Umesh Yadav   20000000        BOWLER              5.8
# 3           3       Robin Minz    2000000  WICKETKEEPER              3.6
# 4           4   Sushant Mishra    2000000        BOWLER              2.2
#
#    Cost IN $ (000) 2023 Squad            Team
# 0           1200.0        NaN  Gujarat Titans
# 1            888.0       PBKS  Gujarat Titans
# 2            696.0        KKR  Gujarat Titans
# 3            432.0        NaN  Gujarat Titans
# 4            264.0        NaN  Gujarat Titans

# %%
ipl.shape
# Out:
# (675, 8)

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       675 non-null    int64
#  1   Player           675 non-null    object
#  2   Base Price       675 non-null    object
#  3   TYPE             333 non-null    object
#  4   COST IN ₹ (CR.)  240 non-null    float64
#  5   Cost IN $ (000)  240 non-null    float64
#  6   2023 Squad       67 non-null     object
#  7   Team             675 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 42.3+ KB

# %%
ipl.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Base Price', 'TYPE', 'COST IN ₹ (CR.)',
#        'Cost IN $ (000)', '2023 Squad', 'Team'],
#       dtype='object')

# %%
ipl.head()
# Out:
#             Player Base Price          TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0  Spencer Johnson    5000000        BOWLER             10.0           1200.0
# 1    Shahrukh Khan    4000000   ALL-ROUNDER              7.4            888.0
# 2      Umesh Yadav   20000000        BOWLER              5.8            696.0
# 3       Robin Minz    2000000  WICKETKEEPER              3.6            432.0
# 4   Sushant Mishra    2000000        BOWLER              2.2            264.0
#
#   2023 Squad            Team
# 0        NaN  Gujarat Titans
# 1       PBKS  Gujarat Titans
# 2        KKR  Gujarat Titans
# 3        NaN  Gujarat Titans
# 4        NaN  Gujarat Titans

# %%
ipl.isnull().sum()
# Out:
# Player               0
# Base Price           0
# TYPE               342
# COST IN ₹ (CR.)    435
# Cost IN $ (000)    435
# 2023 Squad         608
# Team                 0
# dtype: int64

# %%
ipl[ipl['Cost IN $ (000)'].isnull()]
# Out:
#                  Player Base Price TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 125    Devdutt Padikkal     Traded  NaN              NaN              NaN
# 149       Hardik Pandya     Traded  NaN              NaN              NaN
# 150    Romario Shepherd     Traded  NaN              NaN              NaN
# 175        Mayank Dagar     Traded  NaN              NaN              NaN
# 176       Cameron Green     Traded  NaN              NaN              NaN
# ..                  ...        ...  ...              ...              ...
# 670    Mitchell Santner   Retained  NaN              NaN              NaN
# 671     Simarjeet Singh   Retained  NaN              NaN              NaN
# 672      Nishant Sindhu   Retained  NaN              NaN              NaN
# 673    Prashant Solanki   Retained  NaN              NaN              NaN
# 674  Maheesh Theekshana   Retained  NaN              NaN              NaN
#
#     2023 Squad                         Team
# 125        NaN         Lucknow Super Giants
# 149        NaN               Mumbai Indians
# 150        NaN               Mumbai Indians
# 175        NaN  Royal Challengers Bengaluru
# 176        NaN  Royal Challengers Bengaluru
# ..         ...                          ...
# 670        NaN                       Unsold
# 671        NaN                       Unsold
# 672        NaN                       Unsold
# 673        NaN                       Unsold
# 674        NaN                       Unsold
#
# [435 rows x 7 columns]

# %%
ipl[ipl['2023 Squad'].isnull()]
# Out:
#                  Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0       Spencer Johnson    5000000        BOWLER             10.0
# 3            Robin Minz    2000000  WICKETKEEPER              3.6
# 4        Sushant Mishra    2000000        BOWLER              2.2
# 6    Azmatullah Omarzai    5000000   ALL-ROUNDER              0.5
# 7          Manav Suthar    2000000        BOWLER              0.2
# ..                  ...        ...           ...              ...
# 670    Mitchell Santner   Retained           NaN              0.0
# 671     Simarjeet Singh   Retained           NaN              0.0
# 672      Nishant Sindhu   Retained           NaN              0.0
# 673    Prashant Solanki   Retained           NaN              0.0
# 674  Maheesh Theekshana   Retained           NaN              0.0
#
#      Cost IN $ (000) 2023 Squad            Team
# 0             1200.0        NaN  Gujarat Titans
# 3              432.0        NaN  Gujarat Titans
# 4              264.0        NaN  Gujarat Titans
# 6               60.0        NaN  Gujarat Titans
# 7               24.0        NaN  Gujarat Titans
# ..               ...        ...             ...
# 670              NaN        NaN          Unsold
# 671              NaN        NaN          Unsold
# 672              NaN        NaN          Unsold
# 673              NaN        NaN          Unsold
# 674              NaN        NaN          Unsold
#
# [608 rows x 7 columns]

# %%
ipl['2023 Squad'] = ipl['2023 Squad'].fillna('Not Participated')

# %%
if 'COST IN ₹ (CR.)' in ipl.columns and 'COST IN $ (000)' in ipl.columns:
    # Fill NaN values with 0
    ipl['COST IN ₹ (CR.)'] = ipl['COST IN ₹ (CR.)'].fillna(0)
    ipl['COST IN $ (000)'] = ipl['COST IN $ (000)'].fillna(0)

# %%
ipl.head()
# Out:
#             Player Base Price          TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0  Spencer Johnson    5000000        BOWLER             10.0           1200.0
# 1    Shahrukh Khan    4000000   ALL-ROUNDER              7.4            888.0
# 2      Umesh Yadav   20000000        BOWLER              5.8            696.0
# 3       Robin Minz    2000000  WICKETKEEPER              3.6            432.0
# 4   Sushant Mishra    2000000        BOWLER              2.2            264.0
#
#          2023 Squad            Team status
# 0  Not Participated  Gujarat Titans   sold
# 1              PBKS  Gujarat Titans   sold
# 2               KKR  Gujarat Titans   sold
# 3  Not Participated  Gujarat Titans   sold
# 4  Not Participated  Gujarat Titans   sold

# %%
ipl.isnull().sum()
# Out:
# Player               0
# Base Price           0
# TYPE               342
# COST IN ₹ (CR.)      0
# Cost IN $ (000)    435
# 2023 Squad           0
# Team                 0
# dtype: int64

# %%
teams = ipl[ipl['COST IN ₹ (CR.)']>0]['Team'].unique()
teams
# Out:
# array(['Gujarat Titans', 'Chennai Super Kings', 'Delhi Capital',
#        'Kolkata Knight Riders', 'Punjab Kings', 'Lucknow Super Giants',
#        'Mumbai Indians', 'Royal Challengers Bengaluru',
#        'Rajasthan Royals', 'Sunrisers Hyderabad'], dtype=object)

# %%
#SOld and UNsold
ipl['status'] = ipl['Team'].replace(teams,'sold')

# %%
ipl
# Out:
#                  Player Base Price          TYPE  COST IN ₹ (CR.)  \
# 0       Spencer Johnson    5000000        BOWLER             10.0
# 1         Shahrukh Khan    4000000   ALL-ROUNDER              7.4
# 2           Umesh Yadav   20000000        BOWLER              5.8
# 3            Robin Minz    2000000  WICKETKEEPER              3.6
# 4        Sushant Mishra    2000000        BOWLER              2.2
# ..                  ...        ...           ...              ...
# 670    Mitchell Santner   Retained           NaN              0.0
# 671     Simarjeet Singh   Retained           NaN              0.0
# 672      Nishant Sindhu   Retained           NaN              0.0
# 673    Prashant Solanki   Retained           NaN              0.0
# 674  Maheesh Theekshana   Retained           NaN              0.0
#
#      Cost IN $ (000)        2023 Squad            Team  status
# 0             1200.0  Not Participated  Gujarat Titans    sold
# 1              888.0              PBKS  Gujarat Titans    sold
# 2              696.0               KKR  Gujarat Titans    sold
# 3              432.0  Not Participated  Gujarat Titans    sold
# 4              264.0  Not Participated  Gujarat Titans    sold
# ..               ...               ...             ...     ...
# 670              NaN  Not Participated          Unsold  Unsold
# 671              NaN  Not Participated          Unsold  Unsold
# 672              NaN  Not Participated          Unsold  Unsold
# 673              NaN  Not Participated          Unsold  Unsold
# 674              NaN  Not Participated          Unsold  Unsold
#
# [675 rows x 8 columns]

# %%
ipl[ipl['Player'].duplicated(keep=False)]
# Out:
#                  Player Base Price TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 8          David Miller   Retained  NaN              0.0              0.0
# 9          Shubman Gill   Retained  NaN              0.0              0.0
# 10         Matthew Wade   Retained  NaN              0.0              0.0
# 11      Wriddhiman Saha   Retained  NaN              0.0              0.0
# 12      Kane Williamson   Retained  NaN              0.0              0.0
# ..                  ...        ...  ...              ...              ...
# 670    Mitchell Santner   Retained  NaN              0.0              NaN
# 671     Simarjeet Singh   Retained  NaN              0.0              NaN
# 672      Nishant Sindhu   Retained  NaN              0.0              NaN
# 673    Prashant Solanki   Retained  NaN              0.0              NaN
# 674  Maheesh Theekshana   Retained  NaN              0.0              NaN
#
#            2023 Squad            Team  status
# 8    Not Participated  Gujarat Titans    sold
# 9    Not Participated  Gujarat Titans    sold
# 10   Not Participated  Gujarat Titans    sold
# 11   Not Participated  Gujarat Titans    sold
# 12   Not Participated  Gujarat Titans    sold
# ..                ...             ...     ...
# 670  Not Participated          Unsold  Unsold
# 671  Not Participated          Unsold  Unsold
# 672  Not Participated          Unsold  Unsold
# 673  Not Participated          Unsold  Unsold
# 674  Not Participated          Unsold  Unsold
#
# [341 rows x 8 columns]

# %%
#How Many Players Participated in 2023 Ipl Auction ?
ipl.shape[0]
# Out:
# 675

# %%
#How many types of players have Participated ?

types = ipl['TYPE'].value_counts()
types.reset_index()
# Out:
#            TYPE  count
# 0        BOWLER    130
# 1   ALL-ROUNDER    113
# 2        BATTER     53
# 3  WICKETKEEPER     37

# %%
# Pie Chart 
plt.pie(types.values , labels=types.index,labeldistance=1.2,autopct='%1.2f%%',shadow=True , startangle = 60)
plt.title('Role of Players Participated ' , fontsize =15 )
plt.plot()
# Out:
# []

# %%
# Players Sold and Unsold by Using  bar Graph .
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 5))
fig = sns.countplot(x='status', data=ipl, palette=['Orange', 'Pink'])
plt.xlabel('Sold or Unsold')
plt.ylabel('Number of Players')
plt.title('Sold Vs Unsold', fontsize=15)
plt.show()

for p in fig.patches:
    fig.annotate(format(p.get_height(), '.0f'),
                 (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', xytext=(0, 4), textcoords='offset points')

# %%
ipl.groupby('status')['Player'].count()
# Out:
# status
# Unsold    428
# sold      247
# Name: Player, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 10))
fig = sns.countplot(x=ipl[ipl['Team'] != 'Unsold']['Team'])
plt.xlabel('Team Names')
plt.ylabel('Number of Players')
plt.title('Player Bought by Each Team', fontsize=12)
plt.xticks(rotation=70)
plt.show()

for p in fig.patches:
    fig.annotate(format(p.get_height(), '.0f'), 
                 (p.get_x() + p.get_width() / 2., p.get_height()), 
                 ha='center', va='center', xytext=(0, 4), 
                 textcoords='offset points')

# %%
# NEw Column - Retension alias Base Price 

ipl['Retention'] = ipl['Base Price']

# %%
ipl['Retention'].replace(['2 Cr','40 Lakh','20 Lakh','1 Cr','75 Lakh',
                          '50 Lakh','30 Lakh','1.5 Cr'] ,'from Auction', inplace = True)

# %%
ipl.head()
# Out:
#             Player Base Price          TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0  Spencer Johnson    5000000        BOWLER             10.0           1200.0
# 1    Shahrukh Khan    4000000   ALL-ROUNDER              7.4            888.0
# 2      Umesh Yadav   20000000        BOWLER              5.8            696.0
# 3       Robin Minz    2000000  WICKETKEEPER              3.6            432.0
# 4   Sushant Mishra    2000000        BOWLER              2.2            264.0
#
#          2023 Squad            Team status Retention
# 0  Not Participated  Gujarat Titans   sold   5000000
# 1              PBKS  Gujarat Titans   sold   4000000
# 2               KKR  Gujarat Titans   sold  20000000
# 3  Not Participated  Gujarat Titans   sold   2000000
# 4  Not Participated  Gujarat Titans   sold   2000000

# %%
# Treating Base Price
ipl['Base Price'].replace('Draft Pick',0, inplace = True)

# %%
ipl['base_price_unit'] = ipl['Base Price'].apply(lambda x : str(x).split(' ')[-1])
ipl['base_price'] = ipl['Base Price'].apply(lambda x : str(x).split(' ')[0])

# %%
ipl['base_price'].replace('Retained',0,inplace = True)

# %%
ipl.head()
# Out:
#             Player Base Price          TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 0  Spencer Johnson    5000000        BOWLER             10.0           1200.0
# 1    Shahrukh Khan    4000000   ALL-ROUNDER              7.4            888.0
# 2      Umesh Yadav   20000000        BOWLER              5.8            696.0
# 3       Robin Minz    2000000  WICKETKEEPER              3.6            432.0
# 4   Sushant Mishra    2000000        BOWLER              2.2            264.0
#
#          2023 Squad            Team status Retention base_price_unit  \
# 0  Not Participated  Gujarat Titans   sold   5000000         5000000
# 1              PBKS  Gujarat Titans   sold   4000000         4000000
# 2               KKR  Gujarat Titans   sold  20000000        20000000
# 3  Not Participated  Gujarat Titans   sold   2000000         2000000
# 4  Not Participated  Gujarat Titans   sold   2000000         2000000
#
#   base_price
# 0    5000000
# 1    4000000
# 2   20000000
# 3    2000000
# 4    2000000

# %%
#TOTAL Players Retained and Bought
ipl.groupby(['Team','Retention'])['Retention'].count()[:-1]
# Out:
# Team                 Retention
# Chennai Super Kings  10000000      1
#                      2000000       2
#                      20000000      2
#                      5000000       1
#                      Retained     19
#                                   ..
# Unsold               20000000      9
#                      3000000       6
#                      4000000       2
#                      5000000      45
#                      7500000      10
# Name: Retention, Length: 63, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(20, 10))
fig = sns.countplot(x=ipl[ipl['Team'] != 'Unsold']['Team'], hue=ipl['TYPE'])
plt.xlabel('Team Names')
plt.ylabel('Number of Players')
plt.title('Players In Each Team', fontsize=12)
plt.xticks(rotation=50)
plt.show()

# %%
# Highest Amount spent on a single player by each team

ipl[ipl['Retention'] == 'From Auction'].groupby(['Team'])['COST IN ₹ (CR.)'].max()[:-1].sort_values(ascending = True)
# Out:
# Series([], Name: COST IN ₹ (CR.), dtype: float64)

# %%
# Player Retained at Maximum Price
ipl[ipl['Retention'] == 'Retained'].sort_values(by='COST IN ₹ (CR.)', ascending = False).head(1)
# Out:
#          Player Base Price TYPE  COST IN ₹ (CR.)  Cost IN $ (000)  \
# 8  David Miller   Retained  NaN              0.0              0.0
#
#          2023 Squad            Team status Retention base_price_unit  \
# 8  Not Participated  Gujarat Titans   sold  Retained        Retained
#
#   base_price
# 8          0

# %%
# Top 5 Bowlers
ipl[(ipl['Retention'] ==' From Auction') & (ipl['TYPE']=='BOWLER')].sort_values(by='COST IN ₹ (CR.)',ascending = False)
# Out:
# Empty DataFrame
# Columns: [Player, Base Price, TYPE, COST IN ₹ (CR.), Cost IN $ (000), 2023 Squad, Team, status, Retention, base_price_unit, base_price]
# Index: []

# %%
# Top 5 Bastam
ipl[(ipl['Retention'] ==' From Auction') & (ipl['TYPE']=='BATTER')].sort_values(by='COST IN ₹ (CR.)',ascending = False)
# Out:
# Empty DataFrame
# Columns: [Player, Base Price, TYPE, COST IN ₹ (CR.), Cost IN $ (000), 2023 Squad, Team, status, Retention, base_price_unit, base_price]
# Index: []

# %%
ipl = ipl.rename(columns={'2023 Squad' : 'Prev_team'})

# %%
# Assuming 'ipl' is your DataFrame

unsold_players = ipl[(ipl['Prev_team'] != 'Not Participated') & (ipl['Team'] == 'Unsold')][['Player', 'Prev_team']]

# %%
print(unsold_players)
# Out:
#                   Player Prev_team
# 247           Karun Nair       LSG
# 251          Philip Salt        DC
# 252       Josh Hazlewood       RCB
# 253         Akeal Hosein       SRH
# 254          Adil Rashid       SRH
# 260          Manan Vohra       LSG
# 261       Raj Angad Bawa      PBKS
# 262        Sarfaraz Khan        DC
# 263       Vivrant Sharma       SRH
# 265      Hrithik Shokeen        MI
# 266          Urvil Patel        GT
# 269         Kuldip Yadav        RR
# 270        Murgan Ashwin        RR
# 273           Finn Allen       RCB
# 291    Michael Bracewell       RCB
# 296         Jason Holder        RR
# 303     Dwaine Pretorius       CSK
# 304          Daniel Sams       LSG
# 305        Dasun Shanaka        GT
# 307          Odean Smith        GT
# 320        Kyle Jamieson       CSK
# 321         Chris Jordan        MI
# 322       Siddharth Kaul       RCB
# 324           Obed Mccoy        RR
# 325       Riley Meredith        MI
# 327           Adam Milne       CSK
# 331        Wayne Parnell       RCB
# 334          Tim Southee       KKR
# 339      Sandeep Warrier        MI
# 360  Subhranshu Senapati       CSK
# 367           P.A. Abdul        RR
# 379          Aarya Desai       KKR
# 387          Duan Jansen        MI
# 389            Aman Khan        DC
# 400    Kamlesh Nagarkoti        DC
# 410         Mohit Rathee      PBKS
# 423          David Wiese       KKR
# 445             K.M Asif        RR
# 452   Gurnoor Singh Brar      PBKS
# 457        Arpit Guleria       LSG
# 463   Kulwant Khejroliya       KKR
# 491         K.C Cariappa        RR
# 497         Raghav Goyal        MI
